# %%
from logicqubit.logic import *

# %%
logicQuBit = LogicQuBit(2, symbolic=True, first_left=False)

q1 = Qubit()
q2 = Qubit()

logicQuBit.PrintState()
# Out:
# $\displaystyle \left[\begin{matrix}a2_{0}a1_{0}\\a2_{0}b1_{1}\\b2_{1}a1_{0}\\b2_{1}b1_{1}\end{matrix}\right]$

# %%
q1.H()
q2.CX(q1)

logicQuBit.PrintState()
# Out:
# $\displaystyle \left[\begin{matrix}0.707106781186547a2_{0}a1_{0} + 0.707106781186547a2_{0}b1_{1}\\0.707106781186547b2_{1}a1_{0} - 0.707106781186547b2_{1}b1_{1}\\0.707106781186547b2_{1}a1_{0} + 0.707106781186547b2_{1}b1_{1}\\0.707106781186547a2_{0}a1_{0} - 0.707106781186547a2_{0}b1_{1}\end{matrix}\right]$

# %%
logicQuBit.setSymbolValuesForAll(1, 0) # a=1, b=0

# %%
logicQuBit.PlotDensityMatrix()

# %%
res = logicQuBit.Measure([q1,q2])
logicQuBit.Plot()
