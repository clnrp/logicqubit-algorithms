# %%
from logicqubit.logic import *
# Out:
# Cuda is not available!
# logicqubit version 1.5.6

# %%
logicQuBit  = LogicQuBit(2)

x1 = Qubit()
x2 = Qubit()

#y = Qubit()
#y.X()

x1.H()
x2.H()

x1.X()
x1.CZ(x2)
x1.X()

#x2.X()
#x2.CZ(x1)
#x2.X()

# %%
logicQuBit.getDictPsi()
# Out:
# {'00': (0.4999999999999999+0j),
#  '01': (-0.4999999999999999+0j),
#  '10': (0.4999999999999999+0j),
#  '11': (0.4999999999999999+0j)}

# %%
logicQuBit.PlotDensityMatrix()

# %%
DensityMatrix = logicQuBit.DensityMatrix().get()

# %%
DensityMatrix
# Out:
# array([[ 0.25+0.j, -0.25+0.j,  0.25+0.j,  0.25+0.j],
#        [-0.25+0.j,  0.25+0.j, -0.25+0.j, -0.25+0.j],
#        [ 0.25+0.j, -0.25+0.j,  0.25+0.j,  0.25+0.j],
#        [ 0.25+0.j, -0.25+0.j,  0.25+0.j,  0.25+0.j]])
