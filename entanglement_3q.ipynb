# %%
from logicqubit.logic import *

# %%
logicQuBit  = LogicQuBit(3)

q1 = Qubit()
q2 = Qubit()
q3 = Qubit()

# %%
q1.H()
q2.CNOT(q1)
q3.CNOT(q2)

# %%
logicQuBit.PlotDensityMatrix()

# %%
#logicQuBit.Measure_One(q1)

# %%
logicQuBit.PlotDensityMatrix()

# %%
logicQuBit.Measure([q1,q2,q3])
# Out:
# [(0.4999999999999999+0j), 0j, 0j, 0j, 0j, 0j, 0j, (0.4999999999999999+0j)]

# %%
logicQuBit.Plot()
